# %% [markdown]
# # Aufgabe 3.10: Halbierungsmaschine (Lösung)
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** `while`, `//`, Zähler

# %% [markdown]
# ## Briefing
#
# In der MotoTec-Fertigung werden Stahlblöcke schrittweise halbiert, um dünnere Bleche
# herzustellen. Dabei wird das Gewicht des Blocks in jedem Schritt ganzzahlig halbiert.
# Irgendwann ist der Block so leicht, dass eine weitere Halbierung nicht mehr möglich ist,
# weil das Gewicht ungerade wird. Ihre Aufgabe ist es zu berechnen, wie oft ein Stahlblock
# halbiert werden kann, bevor er nicht mehr durch 2 teilbar ist.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Tarek Özdal steht an der Walzstraße und betrachtet einen massiven Stahlblock.*
#
# > *„Wie dünn können wir das Blech schneiden? Wir halbieren den Block immer
# > wieder, bis es nicht mehr geht. Ich brauche ein Programm, das mir zeigt, wie oft
# > wir halbieren können und was nach jedem Schritt übrig bleibt. Rechnen Sie das aus.“*

# %% [markdown]
# ## Beispiele
#
# Eine `while`-Schleife wiederholt einen Codeblock, solange eine Bedingung erfüllt ist.
# Mit `//` führen Sie eine ganzzahlige Division durch (das Ergebnis wird abgerundet).

# %%
# Beispiel 1: while-Schleife mit Zähler
zaehler = 0
while zaehler < 5:
    print("Zählerstand:", zaehler)
    zaehler += 1
print("Fertig! Schleife lief", zaehler, "Mal.")

# %%
# Beispiel 2: Ganzzahlige Division mit //
print(17 // 2)   # Ergebnis: 8 (abgerundet)
print(10 // 2)   # Ergebnis: 5
print(10 % 2)    # Ergebnis: 0 (kein Rest, also durch 2 teilbar)
print(17 % 2)    # Ergebnis: 1 (Rest 1, also nicht durch 2 teilbar)

# %% [markdown]
# ## Aufgabe
#
# **(a)** Lesen Sie das Gewicht des Stahlblocks ein.
#
# **(b)** Speichern Sie das ursprüngliche Gewicht in einer separaten Variable.
#
# **(c)** Halbieren Sie den Block schrittweise (ganzzahlig), solange er durch 2 teilbar ist. Zählen Sie die Schritte mit.
#
# **(d)** Geben Sie jeden Halbierungsschritt aus: `"Schritt X: Y kg → Z kg"`
#
# **(e)** Geben Sie am Ende aus, wie oft der Block halbiert werden konnte.

# %%
# === Aufgabe (a): Gewicht des Stahlblocks einlesen ===
print("Wie schwer ist der Stahlblock (in kg)?")
stahlblock_gewicht = int(input())

# === Aufgabe (b): Ursprüngliches Gewicht speichern ===
urspruengliches_gewicht = stahlblock_gewicht

# === Aufgabe (c): Halbierung in einer while-Schleife ===
zaehler = 0

while stahlblock_gewicht % 2 == 0:
    neues_gewicht = stahlblock_gewicht // 2
    zaehler += 1

    # === Aufgabe (d): Jeden Schritt ausgeben ===
    print(f"Schritt {zaehler}: {stahlblock_gewicht} kg \u2192 {neues_gewicht} kg")

    stahlblock_gewicht = neues_gewicht

# === Aufgabe (e): Endergebnis ausgeben ===
print(f"Der Stahlblock kann {zaehler} mal halbiert werden.")

# %% [markdown]
# ## Debriefing
#
# *Tarek Özdal notiert sich die Ergebnisse auf seinem Klemmbrett:*
#
# > *"Sehr gut, jetzt sehe ich genau, wie oft wir den Block halbieren können. Mit diesen Daten kann ich die Walzstraße besser planen. Wenn ich weiß, wie viele Schritte es braucht, kann ich die Maschinenlaufzeiten genauer kalkulieren. Weiter so."*
