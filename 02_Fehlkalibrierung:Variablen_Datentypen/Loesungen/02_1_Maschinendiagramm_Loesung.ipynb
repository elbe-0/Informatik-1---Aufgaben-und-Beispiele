# %% [markdown]
# # Aufgabe 2.1: Maschinendiagramm bereinigen (Lösung)
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** Kommentare (`#`), Code-Dokumentation, visuelles Feedback

# %% [markdown]
# ## Briefing
#
# Das Terminal läuft, aber die Sensoren liefern falsche Werte. Temperatur als Text, negative Drehzahlen - irgendjemand hat die Konfiguration verhunzt. Dr. Lena Voss von der Qualitätssicherung hat die Leitung übernommen. Ihr erster Blick gilt dem Maschinendiagramm: Es zeigt die Temperaturdaten der Fertigungsstraße, aber irgendetwas stimmt nicht. Testdaten, falsche Achsenbeschriftungen und Debug-Reste machen die Grafik unbrauchbar.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Dr. Lena Voss (Qualitätsmanagerin) steht mit verschränkten Armen vor dem Bildschirm. Ihr Blick ist analytisch und unzufrieden:*
#
# > *"Das Diagramm ist unbrauchbar - Testdaten, falsche Achsen, Debug-Reste. Räumt das auf und dokumentiert, was ihr gemacht habt. Eins nach dem anderen."*

# %% [markdown]
# ## Beispiele
#
# Mit dem Zeichen `#` können Sie Teile des Codes von der Ausführung ausschließen. Alles nach `#` in einer Zeile wird von Python ignoriert:

# %%
# Diese Zeile wird nicht ausgeführt
print("Diese Zeile wird ausgeführt")
# print("Diese Zeile wird NICHT ausgeführt")
print("Diese Zeile auch")  # Kommentar am Zeilenende

# %% [markdown]
# Kommentare können auch dazu dienen, Code zu **dokumentieren** - also zu erklären, was der Code tut:

# %%
# Programm: Temperaturumrechnung
# Autor: IT-Team MotoTec
# Datum: 2024-10-15

# Temperatur in Celsius
temperatur_c = 85.5

# Umrechnung in Fahrenheit
temperatur_f = temperatur_c * 9/5 + 32

print("Temperatur:", temperatur_f, "°F")

# %% [markdown]
# ## Aufgabe
#
# Das folgende Diagramm zeigt die Temperaturdaten der Fertigungsstraße - aber es enthält Fehler. Der gesamte Code ist vorgegeben. Sie schreiben **keinen eigenen Code**, sondern verändern die Grafik ausschließlich durch **Auskommentieren** (Zeile mit `#` deaktivieren) bzw. **Einkommentieren** (vorhandenes `#` entfernen).
#
# **(a)** Führen Sie den Code zunächst unverändert aus und betrachten Sie das Diagramm. Was stimmt nicht?
#
# **(b)** Bereinigen Sie das Diagramm, indem Sie die fehlerhaften Zeilen auskommentieren:
# - Die **Testdaten** (rote Linie) müssen entfernt werden
# - Die **falsche Achsenbeschriftung** muss deaktiviert werden
# - Die **Debug-Ausgabe** (`print(...)`) soll nicht mehr erscheinen
# - Die **korrekte Achsenbeschriftung** ist bereits im Code vorhanden, aber auskommentiert - aktivieren Sie sie
#
# **(c)** Ergänzen Sie einen **Dokumentations-Header** am Anfang der Code-Zelle (als Kommentare): Programmname, Ihr Name, heutiges Datum.

# %%
# === Aufgabe (c): Dokumentations-Header ===
# Programm: Maschinendiagramm Fertigungsstraße
# Autor: Max Mustermann
# Datum: 2024-10-22

import matplotlib.pyplot as plt

# Messzeitpunkte (Stunden)
stunden = [8, 9, 10, 11, 12, 13, 14, 15, 16]

# Echte Temperaturdaten der Fertigungsstraße (°C)
temperatur = [72, 74, 78, 81, 83, 80, 77, 75, 73]

# === Aufgabe (b): Testdaten auskommentiert ===
#testdaten = [50, 95, 30, 100, 20, 110, 40, 90, 60]

# === Aufgabe (b): Debug-Ausgabe auskommentiert ===
#print("DEBUG: Anzahl Messwerte =", len(temperatur))
#print("DEBUG: Testdaten aktiv!")

plt.figure(figsize=(8, 4))

# Echte Messdaten
plt.plot(stunden, temperatur, 'b-o', label='Temperatur')

# === Aufgabe (b): Testdaten-Plot auskommentiert ===
#plt.plot(stunden, testdaten, 'r--x', label='TESTDATEN')

# === Aufgabe (b): Falsche Achsenbeschriftung auskommentiert ===
#plt.xlabel('Gewicht (kg)')
#plt.ylabel('Geschwindigkeit (km/h)')

# === Aufgabe (b): Korrekte Achsenbeschriftung einkommentiert ===
plt.xlabel('Uhrzeit (Stunde)')
plt.ylabel('Temperatur (°C)')

plt.title('Fertigungsstraße - Temperaturverlauf')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Debriefing
#
# *Dr. Lena Voss betrachtet das bereinigte Diagramm. Ein knappes, zufriedenes Nicken.*
#
# > *"So sieht ein sauberes Diagramm aus. Testdaten raus, richtige Achsen drin, kein Debug-Müll. Und der Header oben - genau so will ich das sehen. Wer später diesen Code liest, weiß sofort was Sache ist. Weiter."*
