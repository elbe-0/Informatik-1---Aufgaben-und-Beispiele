# %% [markdown]
# # Aufgabe 2.5: Werkzeugkasten aktivieren (Lösung)
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** Bibliotheken: `import`, `math`, `random`, `time`

# %% [markdown]
# ## Briefing
#
# Die Sensoren liefern wieder korrekte Werte. Aber für die Reparatur der Fertigungsstraße braucht das Team mehr Werkzeuge: Wurzelberechnungen für Toleranzgrenzen, Zufallswerte für Testsimulationen, Zeitstempel für Protokolle. Python bringt diese Werkzeuge als **Bibliotheken** mit - fertige Sammlungen von Befehlen, die nur aktiviert werden müssen.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Dr. Lena Voss öffnet eine Schublade voller Spezialwerkzeuge:*
#
# > *"Python kann von Haus aus die Grundlagen. Aber für ernsthafte Arbeit brauchen wir Spezialwerkzeuge - Mathematik, Zufallszahlen, Zeitfunktionen. Die sind alle schon da, müssen nur aktiviert werden. Schaut euch an, was wir zur Verfügung haben."*

# %% [markdown]
# ---
#
# **Hinweis:** Dies ist ein **Demonstrations-Notebook**. Führen Sie die Code-Zellen der Reihe nach aus und beobachten Sie die Ergebnisse. Es gibt keine Aufgabe zum Lösen.
#
# ---

# %% [markdown]
# ## `math` - Mathematische Funktionen
#
# Mit `import math` stehen mathematische Standardfunktionen zur Verfügung:

# %%
import math

# Toleranzberechnung: Wurzel aus der Varianz ergibt die Standardabweichung
varianz = 16.0
toleranz = math.sqrt(varianz)
print("Varianz:", varianz)
print("Toleranzgrenze (Standardabweichung):", toleranz)

# Kreisumfang einer Welle berechnen
radius = 5.0  # cm
umfang = 2 * math.pi * radius
print("Wellenumfang:", umfang, "cm")

# Aufrunden mit ceil()
materialverbrauch = 7.2  # Einheiten
bestellung = math.ceil(materialverbrauch)
print("Materialverbrauch:", materialverbrauch, "-> Bestellung:", bestellung, "Einheiten")

# %% [markdown]
# ## `random` - Zufallszahlen
#
# Für Testsimulationen und Stichproben brauchen wir Zufallszahlen:

# %%
import random

# Zufällige Testtemperatur zwischen 50 und 90 Grad
test_temperatur = random.randint(50, 90)
print("Simulierte Temperatur:", test_temperatur, "°C")

# Nochmal ausführen - jedes Mal ein anderer Wert!
test_temperatur = random.randint(50, 90)
print("Simulierte Temperatur:", test_temperatur, "°C")

# %% [markdown]
# ## `time` - Zeit und Verzögerungen
#
# Für Logeinträge und Wartepausen:

# %%
import time

# Aktuelle Zeit als Zeitstempel
zeitstempel = time.strftime("%d.%m.%Y %H:%M:%S", time.localtime())
print("Logeintrag:", zeitstempel, "- System gestartet")

# %%
# Verzögerung im Programmablauf
print("Sensor wird kalibriert...")
time.sleep(2)
print("Kalibrierung abgeschlossen.")

# %%
# Alles zusammen: Logeintrag mit Zeitstempel
zeitstempel = time.strftime("%H:%M:%S", time.localtime())
print("[" + zeitstempel + "] Temperatur:", random.randint(70, 85), "°C")

time.sleep(1)

zeitstempel = time.strftime("%H:%M:%S", time.localtime())
print("[" + zeitstempel + "] Temperatur:", random.randint(70, 85), "°C")

# %% [markdown]
# ## Debriefing
#
# *Dr. Lena Voss schließt die Werkzeugschublade.*
#
# > *"Gut. `math` für Berechnungen, `random` für Simulationen, `time` für Protokolle und Pausen. Das sind eure Werkzeuge ab jetzt. In den nächsten Aufgaben werdet ihr sie brauchen."*
