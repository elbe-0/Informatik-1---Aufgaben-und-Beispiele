# %% [markdown]
# # Aufgabe 1.3: Statusanzeige
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** Steuerzeichen: `\n`, `\t`, `\r`, `\b`, `print(end="")`

# %% [markdown]
# ## Briefing
#
# Das Terminal läuft, die Stromversorgung ist geprüft - aber der Bildschirm zeigt nur wirren Text. Die Statusanzeige des Fabriksystems ist völlig unformatiert: Meldungen ohne Absätze, Tabellen ohne Spalten, alles ein unlesbarer Block. Bevor das Team die einzelnen Systeme hochfahren kann, muss die Statusanzeige repariert werden - sonst weiß niemand, welches System läuft und welches nicht.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Sandra Holz (IT-Leiterin) beugt sich stirnrunzelnd zum Bildschirm. Die Zeilen laufen unformatiert ineinander:*
#
# > *"Die Statusanzeige muss lesbar sein. Formatiert das sauber. Ich brauch Tabulatoren für die Spalten, saubere Zeilenumbrüche und am Ende einen Ladebalken, der den Systemstart anzeigt. Ohne ordentliche Anzeige arbeiten wir hier blind."*

# %% [markdown]
# ## Beispiele
#
# Steuerzeichen beeinflussen die Ausgabe direkt. Führen Sie die folgenden Zellen aus:

# %%
print("Zeile 1")
print("Zeile 2")

# %% [markdown]
# `\n` erzeugt einen zusätzlichen Zeilenumbruch innerhalb eines Strings:

# %%
print("System:\nStrom\nWasser\nNetzwerk")

# %% [markdown]
# `\t` erzeugt einen Tabulator-Abstand:

# %%
print("System:\tStatus")
print("Strom:\tOK")

# %% [markdown]
# `print(end="")` unterdrückt den automatischen Zeilenumbruch:

# %%
print("Laden", end="")
print("...fertig!")

# %% [markdown]
# ## Aufgabe
#
# Reparieren Sie die Statusanzeige des MotoTec-Terminals mit Hilfe von Steuerzeichen:
#
# **(a)** Erstellen Sie ein formatiertes Status-Dashboard mit `\t` (Tabulator) und `\n` (Zeilenumbruch). Die Ausgabe soll so aussehen:
#
# ```
# === MOTOTEC SYSTEM-STATUS ===
#
# System		Status		Priorität
# -------		------		----------
# Strom		ONLINE		HOCH
# Netzwerk	OFFLINE		HOCH
# Beleuchtung	OFFLINE		MITTEL
# Heizung		OFFLINE		NIEDRIG
# ```
#
# Verwenden Sie `\t` für die Spaltenausrichtung und `\n` für die Zeilenumbrüche. Sie können mehrere `print()`-Aufrufe verwenden oder alles in einem einzigen `print()` mit `\n` ausgeben.
#
# **(b)** Testen Sie die Steuerzeichen `\b` (Backspace) und `\r` (Carriage Return). Führen Sie die folgenden Zeilen aus und beobachten Sie die Ausgabe:
#
# ```python
# print("Status: FEHLERR\b ")
# print("Ladevorgang...\rFERTIG")
# ```
#
# Erklären Sie als Kommentar im Code: Was bewirkt `\b`? Was bewirkt `\r`?
#
# **(c)** Bauen Sie einen Ladebalken für den Systemstart. Die Vorlage unten verwendet `import time` und eine `while`-Schleife - diese Werkzeuge werden später im Kurs erklärt. Ihre Aufgabe ist es, die `print()`-Zeile so anzupassen, dass der Ladebalken sich **auf derselben Zeile aktualisiert** (mit `\r` und `end=""`).

# %%
# (a) Status-Dashboard mit \t und \n formatieren:

# %%
# (b) Steuerzeichen \b und \r testen:


# Was bewirkt \b?
# Ihre Erklärung: ...

# Was bewirkt \r?
# Ihre Erklärung: ...

# %%
# (c) Ladebalken für den Systemstart
# Die folgenden Zeilen sind vorgegeben - ändern Sie nur die print()-Zeile!

import time

print("Systemstart wird eingeleitet...")

fortschritt = 0
while fortschritt <= 100:
    balken = "#" * (fortschritt // 5)
    luecke = "." * (20 - fortschritt // 5)

    # IHRE AUFGABE: Passen Sie die folgende print()-Zeile an.
    # Verwenden Sie \r am Anfang des Strings und end="",
    # damit der Balken sich auf derselben Zeile aktualisiert.
    print("[" + balken + luecke + "] " + str(fortschritt) + "%")

    time.sleep(0.1)
    fortschritt = fortschritt + 5

print("\nAlle Systeme bereit.")
