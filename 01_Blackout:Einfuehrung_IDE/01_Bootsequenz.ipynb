# %% [markdown]
# # Aufgabe 1.1: Bootsequenz
#
# **Autor:** Informatik I - Mission MotoTec
# **Datum:** 2026
# **Thema:** Erste Schritte mit `print()`, `input()` und Strings
# **Schwierigkeit:** 1/5

# %% [markdown]
# ## Briefing
#
# Die Fabrikhalle der MotoTec GmbH liegt im Dunkeln. Seit dem IT-Totalausfall vor drei Stunden reagiert kein einziges System mehr - keine Beleuchtung, keine Maschinensteuerung, keine Kommunikation. Das IT-Notfallteam wurde gerufen und steht jetzt vor dem Hauptterminal im Serverraum. Sandra Holz, die IT-Leiterin, leuchtet mit einer Taschenlampe auf den Bildschirm. Er ist schwarz. Alles muss von Grund auf neu gestartet werden.

# %% [markdown]
# ## Stakeholder
#
# *Sandra Holz (IT-Leiterin) steht angespannt am Terminal. Sie spricht knapp und ohne Umschweife:*
#
# > *"Keine Zeit fuer Erklaerungen. Terminal an. Ich brauche eine Bootsequenz, die das System hochfaehrt und den Techniker registriert. Drei Dinge: Bootmeldung ausgeben, Name eingeben, Bestaetigung anzeigen. Los."*

# %% [markdown]
# ## Aufgabe
#
# Schreibe ein Python-Programm, das die Notfall-Bootsequenz des MotoTec-Terminals durchfuehrt:
#
# **(a)** Gib eine Bootsequenz-Meldung auf dem Bildschirm aus. Das Terminal soll beim Hochfahren folgende Zeilen anzeigen:
#
# ```
# === MOTOTEC SYSTEMS v3.7 ===
# Notfall-Boot wird eingeleitet...
# ```
#
# Verwende dazu den `print()`-Befehl.
#
# **(b)** Frage den Namen des Technikers ab. Das Terminal muss wissen, wer sich anmeldet. Verwende den `input()`-Befehl, um den Namen einzulesen und in einer Variable zu speichern.
#
# **(c)** Gib eine personalisierte Statusmeldung aus. Nutze den eingegebenen Namen, um eine Bestaetigung anzuzeigen, z.B.:
#
# ```
# Techniker Max Mustermann angemeldet.
# System bereit. Warte auf Anweisungen...
# ```
#
# Verwende dazu String-Verkettung mit `+`.
#
# ---
#
# **Hinweise:**
# - `print("Text")` gibt Text auf dem Bildschirm aus
# - `input("Frage: ")` wartet auf eine Eingabe und gibt den eingegebenen Text zurueck
# - Mit `+` kannst du Strings (Texte) aneinanderhaengen: `"Hallo " + name`
# - `print()` ohne Inhalt erzeugt eine Leerzeile

# %%
# Dein Code hier:

# %% [markdown]
# ## Debriefing
#
# *Sandra Holz blickt auf den Bildschirm. Ein kurzes Nicken.*
#
# > *"Terminal laeuft. Erster Schritt geschafft. Aber das war der einfache Teil - die eigentlichen Probleme fangen jetzt erst an."*
