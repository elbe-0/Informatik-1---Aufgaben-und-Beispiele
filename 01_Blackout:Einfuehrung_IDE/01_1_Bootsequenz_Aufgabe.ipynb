# %% [markdown]
# # Aufgabe 1.1: Bootsequenz
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** Erste Schritte mit `print()`, `input()` und Strings

# %% [markdown]
# ## Briefing
#
# Die Fabrikhalle der MotoTec GmbH liegt im Dunkeln. Seit dem IT-Totalausfall vor drei Stunden reagiert kein einziges System mehr - keine Beleuchtung, keine Maschinensteuerung, keine Kommunikation. Das IT-Notfallteam wurde gerufen und steht jetzt vor dem Hauptterminal im Serverraum. Sandra Holz, die IT-Leiterin, leuchtet mit einer Taschenlampe auf den Bildschirm. Er ist schwarz. Alles muss von Grund auf neu gestartet werden.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Sandra Holz (IT-Leiterin) steht angespannt am Terminal. Sie spricht knapp und ohne Umschweife:*
#
# > *"Keine Zeit für Erklärungen. Terminal an. Ich brauche eine Bootsequenz, die das System hochfährt und den Techniker registriert. Drei Dinge: Bootmeldung ausgeben, Name eingeben, Bestätigung anzeigen. Los."*

# %% [markdown]
# ## Beispiele
#
# Bevor Sie die Aufgabe lösen, probieren Sie die folgenden Befehle aus:

# %%
print("System gestartet.")
print("Alle Sensoren aktiv.")

# %% [markdown]
# Mit `input()` können Sie Text vom Benutzer einlesen. Der eingegebene Text wird in einer Variable gespeichert und kann anschließend mit `+` an andere Strings angehängt werden:

# %%
name = input("Ihr Name: ")
print("Willkommen, " + name + "!")

# %% [markdown]
# ## Aufgabe
#
# Schreiben Sie ein Python-Programm, das die Notfall-Bootsequenz des MotoTec-Terminals durchführt:
#
# **(a)** Geben Sie eine Bootmeldung auf dem Bildschirm aus:
#
# ```
# === MOTOTEC SYSTEMS v3.7 - Notfall-Boot ===
# ```
#
# Verwenden Sie dazu den `print()`-Befehl.
#
# **(b)** Fragen Sie den Namen des Technikers ab. Das Terminal muss wissen, wer sich anmeldet. Verwenden Sie den `input()`-Befehl, um den Namen einzulesen und in einer Variable zu speichern.
#
# **(c)** Geben Sie eine personalisierte Statusmeldung aus. Nutzen Sie den eingegebenen Namen, um eine Bestätigung anzuzeigen, z.B.:
#
# ```
# Techniker Max Mustermann angemeldet.
# ```
#
# Verwenden Sie dazu String-Verkettung mit `+`.

# %%
# (a) Bootsequenz ausgeben:


# (b) Techniker-Name eingeben:


# (c) Personalisierte Statusmeldung ausgeben:
