# %% [markdown]
# # Aufgabe 4.2: Teilelager digitalisieren
#
# **Modul:** Informatik I - Mission MotoTec
# **Thema:** `list`, `for x in list`, `print()`

# %% [markdown]
# ## Briefing
#
# Im Teilelager klebt an jedem Regal ein handgeschriebener Zettel mit dem Inhalt.
# Jürgen Brandt, der Lagerleiter, hat genug davon: Die Zettel fallen ab, werden
# unleserlich oder verschwinden ganz. Ab sofort soll das Lager digital erfasst werden.
# Im ersten Schritt überführen Sie einzelne Teile-Variablen in eine Python-Liste
# und geben die Inventarliste per `for`-Schleife strukturiert aus.

# %% [markdown]
# ## Stakeholder-Dialog
#
# *Jürgen Brandt, Lagerleiter, steht zwischen den Regalen und zeigt auf vergilbte Zettel:*
#
# > *"Einzelne Zettel am Regal sind vorbei. Ab jetzt digitale Inventarliste.
# > Fangt mit den vier wichtigsten Teilen an und baut das dann aus."*

# %% [markdown]
# ## Beispiele
#
# Die folgenden Beispiele zeigen die wichtigsten Listen-Operationen im Fabrikkontext.

# %%
# --- Listen-Grundlagen im Fabrikkontext ---

# Liste erstellen
maschinen = ["Presse", "Fräse", "Drehbank"]
print("Maschinen:", maschinen)

# Auf einzelne Elemente zugreifen (Index beginnt bei 0)
print("Erste Maschine:", maschinen[0])   # Presse
print("Letzte Maschine:", maschinen[-1])  # Drehbank

# Länge einer Liste
print("Anzahl:", len(maschinen))  # 3

# Iteration mit for-Schleife
print("\nSchichtplan:")
schichten = ["Frühschicht", "Spätschicht", "Nachtschicht"]
for schicht in schichten:
    print("-", schicht)

# Element anhängen mit append()
maschinen.append("Schweißroboter")
print("\nNach append:", maschinen)

# Nummerierte Ausgabe mit enumerate()
print("\nMaschinenliste:")
for i, m in enumerate(maschinen, start=1):
    print(f"{i}. {m}")

# %% [markdown]
# ## Aufgabe
#
# Im Lager sind aktuell vier Teile als einzelne Variablen erfasst:
#
# ```python
# teil1 = "Kolben"
# teil2 = "Dichtung"
# teil3 = "Zündkerze"
# teil4 = "Keilriemen"
# ```
#
# **(a)** Erstellen Sie aus den vier Variablen eine Liste namens `lager`.
#
# **(b)** Geben Sie alle Teile mit einer `for`-Schleife aus (ein Teil pro Zeile).
#
# **(c)** Fügen Sie ein fünftes Teil `"Ölfilter"` mit `append()` zur Liste hinzu.
#
# **(d)** Geben Sie die aktualisierte Liste nummeriert aus, z. B.:
# ```
# 1. Kolben
# 2. Dichtung
# 3. Zündkerze
# 4. Keilriemen
# 5. Ölfilter
# ```

# %%
# Einzelne Teile-Variablen
teil1 = "Kolben"
teil2 = "Dichtung"
teil3 = "Zündkerze"
teil4 = "Keilriemen"

# (a) Liste erstellen


# (b) Alle Teile mit for-Schleife ausgeben


# (c) Fünftes Teil hinzufügen


# (d) Nummerierte Ausgabe

# %% [markdown]
# ## Hilfestellung
#
# <details>
# <summary>Hinweis zu (a): Liste aus Variablen erstellen</summary>
#
# ```python
# # Variablen in eckige Klammern setzen:
# lager = [teil1, teil2, teil3, teil4]
# ```
# </details>
#
# <details>
# <summary>Hinweis zu (d): Nummerierte Ausgabe</summary>
#
# ```python
# # Variante 1: Mit Zähler-Variable
# nummer = 1
# for teil in lager:
#     print(str(nummer) + ". " + teil)
#     nummer = nummer + 1
#
# # Variante 2: Mit enumerate()
# for i, teil in enumerate(lager, start=1):
#     print(f"{i}. {teil}")
# ```
# </details>
